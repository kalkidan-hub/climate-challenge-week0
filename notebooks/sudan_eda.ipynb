# %% [markdown]
# #### Importing important libraries

# %%
import pandas as pd
import numpy as np
from  scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Loading & Data Parsing

# %%
df = pd.read_csv('../data/sudan.csv')

# %% [markdown]
# ##### Adding a country column

# %%
df["COUNTRY"] = ["SUDAN"] * len(df)

# %% [markdown]
# ##### Convert the YEAR and DOY columns into a proper datetime column

# %%
df["DATETIME"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")

# %% [markdown]
# ##### Extracting Month into its own column

# %%
df["YEAR_MONTH"] = df["DATETIME"].dt.to_period("M")

# %%
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.18    35.55    16.14      19.41          0.0  31.87  3.46
# 1  2015    2  23.92    34.14    15.81      18.33          0.0  23.83  4.24
# 2  2015    3  22.73    31.64    15.09      16.55          0.0  38.21  5.01
# 3  2015    4  19.15    27.35    12.88      14.47          0.0  21.07  5.72
# 4  2015    5  17.54    27.22     9.49      17.73          0.0  21.58  4.28
#
#    WS2M_MAX     PS  QV2M COUNTRY   DATETIME YEAR_MONTH
# 0      5.12  96.54  6.08   SUDAN 2015-01-01    2015-01
# 1      5.10  96.67  4.31   SUDAN 2015-01-02    2015-01
# 2      6.24  96.77  6.42   SUDAN 2015-01-03    2015-01
# 3      6.96  96.93  3.06   SUDAN 2015-01-04    2015-01
# 4      5.82  96.85  2.86   SUDAN 2015-01-05    2015-01

# %% [markdown]
# ### Summary Statistics & Missing-Value Report

# %%
df.replace(-999, np.nan, inplace=True)
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  25.18    35.55    16.14      19.41          0.0  31.87  3.46
# 1     2015    2  23.92    34.14    15.81      18.33          0.0  23.83  4.24
# 2     2015    3  22.73    31.64    15.09      16.55          0.0  38.21  5.01
# 3     2015    4  19.15    27.35    12.88      14.47          0.0  21.07  5.72
# 4     2015    5  17.54    27.22     9.49      17.73          0.0  21.58  4.28
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  27.89    34.69    21.67      13.02          0.0  14.47  3.66
# 4104  2026   87  28.73    36.61    21.34      15.27          0.0   9.75  3.21
# 4105  2026   88  30.06    38.89    21.15      17.74          0.0  11.63  2.41
# 4106  2026   89  32.50    41.53    23.61      17.92          0.0  14.06  2.81
# 4107  2026   90  33.79    42.64    25.73      16.91          0.0  13.89  3.52
#
#       WS2M_MAX     PS  QV2M COUNTRY   DATETIME YEAR_MONTH
# 0         5.12  96.54  6.08   SUDAN 2015-01-01    2015-01
# 1         5.10  96.67  4.31   SUDAN 2015-01-02    2015-01
# 2         6.24  96.77  6.42   SUDAN 2015-01-03    2015-01
# 3         6.96  96.93  3.06   SUDAN 2015-01-04    2015-01
# 4         5.82  96.85  2.86   SUDAN 2015-01-05    2015-01
# ...        ...    ...   ...     ...        ...        ...
# 4103      5.11  96.47  3.52   SUDAN 2026-03-27    2026-03
# 4104      4.40  96.35  2.44   SUDAN 2026-03-28    2026-03
# 4105      3.87  96.10  3.12   SUDAN 2026-03-29    2026-03
# 4106      4.87  95.93  4.18   SUDAN 2026-03-30    2026-03
# 4107      5.00  95.89  4.47   SUDAN 2026-03-31    2026-03
#
# [4108 rows x 15 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# `we don't have -999(null) value in our data. So we don't need to replace it with np.nan`
#
# `We don't have duplicated row, so no need to drop any`

# %%
df.isnull().sum()
# Out:
# YEAR           0
# DOY            0
# T2M            0
# T2M_MAX        0
# T2M_MIN        0
# T2M_RANGE      0
# PRECTOTCORR    0
# RH2M           0
# WS2M           0
# WS2M_MAX       0
# PS             0
# QV2M           0
# COUNTRY        0
# DATETIME       0
# YEAR_MONTH     0
# dtype: int64

# %% [markdown]
# ##### Describe the dataset

# %%
df.describe()
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    28.759007    36.773914    21.508510
# min    2015.000000     1.000000    13.180000    21.040000     5.930000
# 25%    2017.000000    86.000000    25.560000    33.730000    17.497500
# 50%    2020.000000   179.000000    29.160000    37.020000    22.890000
# 75%    2023.000000   272.000000    32.510000    40.330000    25.430000
# max    2026.000000   366.000000    37.990000    45.960000    32.170000
# std       3.248907   106.294767     4.681305     4.400065     5.091142
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     15.265404     0.643875    31.359192     3.484253     5.157378
# min       3.420000     0.000000     4.690000     0.610000     1.030000
# 25%      13.280000     0.000000    17.407500     2.730000     4.267500
# 50%      15.810000     0.000000    26.630000     3.490000     5.120000
# 75%      17.680000     0.010000    40.535000     4.220000     6.020000
# max      22.480000    66.490000    87.160000     7.150000     9.050000
# std       3.298919     3.057672    17.851849     1.040667     1.280238
#
#                 PS         QV2M             DATETIME
# count  4108.000000  4108.000000                 4108
# mean     96.346273     7.864557  2020-08-15 12:00:00
# min      95.660000     1.160000  2015-01-01 00:00:00
# 25%      96.160000     3.730000  2017-10-23 18:00:00
# 50%      96.310000     5.895000  2020-08-15 12:00:00
# 75%      96.510000    12.500000  2023-06-08 06:00:00
# max      97.310000    19.440000  2026-03-31 00:00:00
# std       0.266927     4.880934                  NaN

# %% [markdown]
# `The 75th percentile and the max value of PRECTOTCORR is also has great gap, which suggest there might be outline on PRECTOTCORR feature.`

# %% [markdown]
# ##### Percentage of missing values per column

# %%
n = len(df)
for col in df.columns:
    print(f"{col}: {df[col].isna().sum() / n * 100:.2f}%")
# Out:
# YEAR: 0.00%
# DOY: 0.00%
# T2M: 0.00%
# T2M_MAX: 0.00%
# T2M_MIN: 0.00%
# T2M_RANGE: 0.00%
# PRECTOTCORR: 0.00%
# RH2M: 0.00%
# WS2M: 0.00%
# WS2M_MAX: 0.00%
# PS: 0.00%
# QV2M: 0.00%
# COUNTRY: 0.00%
# DATETIME: 0.00%
# YEAR_MONTH: 0.00%

# %% [markdown]
# ### Outlier Detection & Basic Cleaning

# %% [markdown]
# ##### Computing z-score for numerical columns

# %%
z_df = df.select_dtypes(include=[np.number]).apply(stats.zscore)

# %%
z_df.head()
# Out:
#        YEAR       DOY       T2M   T2M_MAX   T2M_MIN  T2M_RANGE  PRECTOTCORR  \
# 0 -1.579631 -1.685342 -0.764625 -0.278192 -1.054609   1.256503    -0.210603
# 1 -1.579631 -1.675933 -1.033813 -0.598681 -1.119435   0.929083    -0.210603
# 2 -1.579631 -1.666524 -1.288047 -1.166924 -1.260875   0.389446    -0.210603
# 3 -1.579631 -1.657115 -2.052884 -2.142028 -1.695015  -0.241140    -0.210603
# 4 -1.579631 -1.647706 -2.396847 -2.171577 -2.360958   0.747183    -0.210603
#
#        RH2M      WS2M  WS2M_MAX        PS      QV2M
# 0  0.028617 -0.023308 -0.029200  0.725856 -0.365662
# 1 -0.421811  0.726303 -0.044824  1.212941 -0.728342
# 2  0.383806  1.466303  0.845744  1.587621 -0.295995
# 3 -0.576436  2.148641  1.408208  2.187109 -0.984472
# 4 -0.547864  0.764745  0.517640  1.887365 -1.025453

# %% [markdown]
# ##### Flagging out rows with |z-score| > 3, as they're outliers and report their count

# %%
for col in z_df.columns:
    count = z_df[col][z_df[col].abs() > 3].shape[0]
    print(f"{col}: {count} outliers")
# Out:
# YEAR: 0 outliers
# DOY: 0 outliers
# T2M: 3 outliers
# T2M_MAX: 6 outliers
# T2M_MIN: 1 outliers
# T2M_RANGE: 15 outliers
# PRECTOTCORR: 71 outliers
# RH2M: 3 outliers
# WS2M: 4 outliers
# WS2M_MAX: 3 outliers
# PS: 21 outliers
# QV2M: 0 outliers

# %% [markdown]
# Apply IQR(Inner Quartile Range) to cap the outliers.

# %% [markdown]
# `The Interquartile Range (IQR) capping method (often called Winsorization or "clamping") is a popular way to handle outliers without losing the sample size that comes with simply deleting rows.`

# %%
# apply IQR method to columns with outliers
for col in z_df.columns:
    count = z_df[col][z_df[col].abs() > 3].shape[0]
    if count > 3:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
z_df = df.select_dtypes(include=[np.number]).apply(stats.zscore)

# %%
for col in z_df.columns:
    count = z_df[col][z_df[col].abs() > 3].shape[0]
    print(f"{col}: {count} outliers")
# Out:
# YEAR: 0 outliers
# DOY: 0 outliers
# T2M: 3 outliers
# T2M_MAX: 0 outliers
# T2M_MIN: 1 outliers
# T2M_RANGE: 0 outliers
# PRECTOTCORR: 0 outliers
# RH2M: 3 outliers
# WS2M: 0 outliers
# WS2M_MAX: 3 outliers
# PS: 0 outliers
# QV2M: 0 outliers

# %% [markdown]
# ##### Export z dataset

# %%
df.to_csv('../data/sudan_cleaned.csv', index=False)

# %% [markdown]
# ### Time Series Analysis

# %%
monthly_t2m = (
    df.groupby("YEAR_MONTH", as_index=False)["T2M"]
      .mean()
      .rename(columns={"T2M": "T2M_MONTHLY_AVG"})
)

# %%
monthly_t2m.head()
# Out:
#   YEAR_MONTH  T2M_MONTHLY_AVG
# 0    2015-01        20.860323
# 1    2015-02        25.979643
# 2    2015-03        29.602581
# 3    2015-04        29.483000
# 4    2015-05        34.584516

# %%
warm_idx = monthly_t2m["T2M_MONTHLY_AVG"].idxmax()
cool_idx = monthly_t2m["T2M_MONTHLY_AVG"].idxmin()

warm_row = monthly_t2m.loc[warm_idx]
cool_row = monthly_t2m.loc[cool_idx]

# %% [markdown]
# ##### Plot of monthly average T2M as a line chart over the full period

# %%
plt.figure(figsize=(30, 8))
x = monthly_t2m["YEAR_MONTH"].astype(str)
y = monthly_t2m["T2M_MONTHLY_AVG"]

plt.plot(x, y)

plt.scatter(x.iloc[warm_idx], y.iloc[warm_idx], color="red", s=70, zorder=5)
plt.scatter(x.iloc[cool_idx], y.iloc[cool_idx], color="blue", s=70, zorder=5)

# annotate warmest
plt.annotate(
    f"Warmest: {x.iloc[warm_idx]} ({y.iloc[warm_idx]:.2f}°C)",
    xy=(x.iloc[warm_idx], y.iloc[warm_idx]),
    xytext=(10, 12),
    textcoords="offset points",
    color="red",
    arrowprops=dict(arrowstyle="->", color="red")
)

# annotate coolest
plt.annotate(
    f"Coolest: {x.iloc[cool_idx]} ({y.iloc[cool_idx]:.2f}°C)",
    xy=(x.iloc[cool_idx], y.iloc[cool_idx]),
    xytext=(10, -16),
    textcoords="offset points",
    color="blue",
    arrowprops=dict(arrowstyle="->", color="blue")
)

plt.title("Kenya Monthly Average T2M (2015-2026)")
plt.xlabel("Month")
plt.ylabel("T2M Monthly Avg (°C)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot monthly total PRECTOTCORR as a bar chart.

# %%
monthly_prectotcorr = (
    df.groupby("YEAR_MONTH", as_index=False)["PRECTOTCORR"]
    .mean()
    .rename(columns={"PRECTOTCORR": "PRECTOTCORR_MONTHLY_AVG"}))

# %%
monthly_prectotcorr.head()
# Out:
#   YEAR_MONTH  PRECTOTCORR_MONTHLY_AVG
# 0    2015-01                 0.000000
# 1    2015-02                 0.000000
# 2    2015-03                 0.000000
# 3    2015-04                 0.000000
# 4    2015-05                 0.000806

# %%
peak_rain_idx = monthly_prectotcorr["PRECTOTCORR_MONTHLY_AVG"].idxmax()

# %%
plt.figure(figsize=(30, 8))

plt.bar(
    monthly_prectotcorr["YEAR_MONTH"]
    .astype(str), monthly_prectotcorr["PRECTOTCORR_MONTHLY_AVG"]
    )

plt.scatter(
    monthly_prectotcorr["YEAR_MONTH"].astype(str).iloc[peak_rain_idx], 
    monthly_prectotcorr["PRECTOTCORR_MONTHLY_AVG"].iloc[peak_rain_idx], 
    color="red", s=120, zorder=5
)
plt. annotate(
    f"Peak Rain: {monthly_prectotcorr['YEAR_MONTH'].astype(str).iloc[peak_rain_idx]} ({monthly_prectotcorr['PRECTOTCORR_MONTHLY_AVG'].iloc[peak_rain_idx]:.2f} mm/day)",
    xy=(monthly_prectotcorr["YEAR_MONTH"].astype(str).iloc[peak_rain_idx], monthly_prectotcorr["PRECTOTCORR_MONTHLY_AVG"].iloc[peak_rain_idx]),
    )
plt.title("Kenya Monthly Average PRECTOTCORR (2015-2026)")
plt.xlabel("Month")
plt.ylabel("PRECTOTCORR Monthly Avg (mm/day)")
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# `The temperature fluctuation trend of the year seems to repeat itself year after year.`
#
# `Months with high or low precipitation are uniform among years`

# %% [markdown]
# ### Correlation & Relationship Analysis

# %% [markdown]
# ##### Heatmap of correlations across all numeric columns

# %%
num_df = df.select_dtypes(include=[np.number])

corr = num_df.corr()

# heatmap of correlation matrix
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
# Out:
# <Axes: >

# %% [markdown]
# `The three strongest correlations:`
# `T2M_MIN and T2M == 0.94`
# `QV2M and RH2M == 0.94`
# `T2M and T2M_MAX == 0.93`

# %% [markdown]
# ##### Scatter plots: T2M vs. RH2M; T2M_RANGE vs. WS2M

# %%
plt.scatter(df["T2M"], df["RH2M"])
plt.xlabel("Temperature at 2m (T2M)")
plt.ylabel("Humidity at 2m (RH2M)");

# %%
plt.scatter(df["T2M_RANGE"], df["WS2M"])
plt.xlabel("Temperature range at 2m (T2M_RANGE)")
plt.ylabel("Wind speed at 2m (WS2M)");

# %% [markdown]
# ### Distribution Analysis

# %% [markdown]
# ##### Histogram of PRECTOTCORR

# %%
plt.hist(df["PRECTOTCORR"], bins=30)
plt.xlabel("Bias-corrected total daily precipitation (PRECTOTCORR)")
plt.ylabel("Frequency");

# %% [markdown]
# ##### Applying log scaling since it's heavily skewed

# %%
plt.hist(df["PRECTOTCORR"], bins=30)
plt.xscale("log")
plt.xlabel("PRECTOTCORR (log scale)")
plt.ylabel("Frequency");

# %% [markdown]
# ##### Bubble chart: T2M vs. RH2M, bubble size = PRECTOTCORR.

# %%
plt.scatter(
    df["T2M"],
    df["RH2M"],
    s=df["PRECTOTCORR"],
    c=df["PRECTOTCORR"],   # optional: color by same variable
    cmap="viridis",
    edgecolors="k",
    linewidths=0.2
)
